# %% [markdown]
# # Preprocess/Clean Dataset

# %% [markdown]
# ## Import Modules

# %%
from pathlib import Path
from uuid import uuid4
import cv2

# %% [markdown]
# ### Supported File Extentions
# * .mp4
# * .avi

# %%
VIDEO_EXTENSIONS = {
    ".mp4",
    ".avi"
}

# %% [markdown]
# ### Function for extracting frames
# * Accepts Parameter : Input directory, Output directory
# * Checks file extention
# * Loads video
# * Finds FPS
# * Loops through each frames and writes in output directory
# * Uses release method to release video

# %%
def extract_frames(input_directory, output_directory):
    
    # directory configs
    input_directory = Path(input_directory)
    output_directory_directory = Path(output_directory_directory)
    output_dir.mkdir(exist_ok=True)
    
    # loop through each video in directory
    for video_path in input_directory.rglob("*"):
        
        # skip non-video files
        if video_path.suffix.lower() not in VIDEO_EXTENSIONS:
            continue
        
        # capture/load video from video path
        video = cv2.VideoCapture(str(video_path))
        
        # get video fps
        fps = video.get(cv2.CAP_PROP_FPS)
        
        interval = int(fps)
        
        frame_no = 0
        
        # loop through the video
        while True:
            
            #read next frame
            ret, frame = video.read()
            # ret -> True/False of video load
            # frame -> Actual Image
            
            # stop after video ends (ret==False)
            if not ret: break
            
            # frame selection logic
            # 1 frame per second
            if frame_no%interval == 0:
                
                # unique name to avoid confilcts
                filename = f"{uuid4()}-{video_path.stem()}-{uuid4()}.jpg"
                
                # write to output directory
                cv2.imwrite(
                    str(output_directory/filename),
                    frame
                )                
                frame_no+=1
            
            # release video and frees memory
            video.release()
            print(f"Video Saved")
