# %% [markdown]
# # Preprocess/Clean Dataset

# %% [markdown]
# ## Import Modules

# %%
from modules.VideoExtractor import extract_frames

# %% [markdown]
# ### Supported File Extentions
# * .mp4
# * .avi

# %%
VIDEO_EXTENSIONS = {
    ".mp4",
    ".avi"
}
