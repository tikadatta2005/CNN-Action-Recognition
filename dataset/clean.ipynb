# %% [markdown]
# # Preprocess/Clean Dataset

# %% [markdown]
# ## Import Modules

# %%
from pathlib import Path
from uuid import uuid4
import cv2

# %% [markdown]
# ### Supported File Extentions
# * .mp4
# * .avi

# %%
VIDEO_EXTENSIONS = {
    ".mp4",
    ".avi"
}

# %% [markdown]
# ### Function for extracting frames
# * Accepts Parameter : Input directory, Output directory, size
# * Checks file extention
# * Loads video
# * Finds FPS
# * Loops through each frames and writes in output directory
# * Uses release method to release video

# %%
def extract_frames(input_directory, output_directory, size=(224, 224)):
    
    # directory configs
    input_directory = Path(input_directory)
    output_directory = Path(output_directory)
    output_directory.mkdir(exist_ok=True, parents=True)
    
    # loop through each video in directory
    for video_path in input_directory.rglob("*"):
        
        # skip non-video files
        if video_path.suffix.lower() not in VIDEO_EXTENSIONS:
            continue
        
        # capture/load video from video path
        video = cv2.VideoCapture(str(video_path))
        
        # get video fps
        fps = video.get(cv2.CAP_PROP_FPS)
        
        # fallback fps
        if fps is None or fps <= 0: fps = 25
        
        interval = int(fps)
        
        frame_no = 0
        
        # loop through the video
        while True:
            
            # read next frame
            ret, frame = video.read()
            # ret -> True/False of video load
            # frame -> Actual Image
            
            # stop after video ends (ret==False)
            if not ret: break            
            
            # resize frame
            frame = cv2.resize(frame, size)
            
            # frame selection logic
            # 1 frame per second
            if frame_no%interval == 0:
                
                # unique name to avoid confilcts
                filename = f"{video_path.stem}_{frame_no}_{uuid4().hex}.jpg"
                
                # write to output directory
                cv2.imwrite(
                    str(output_directory/filename),
                    frame
                )                
            
            frame_no+=1
            
        # release video and frees memory
        video.release()
        print(f"Done {video_path.name}")

# %% [markdown]
# ### Use extract frames to save data

# %% [markdown]
# Name framed dataset will be extracted first as it has least videos (only six). And will be removing un-necessary frames manually.

# %%
#name-framed dataset
extract_frames(
    input_directory="./raw_data/name-framed", 
    output_directory="./cleaned-dataset/violent", 
    size=(224, 224))
# Out:
# Done 1.mp4
# Done 20-40.mp4
# Done 20.mp4
# Done 3.mp4
# Done 51.mp4
# Done 6-16.mp4

# %% [markdown]
# Real world violence dataset data extraction

# %%
# violence dataset
#C:\Projects\ai_projects\Human Action Detection\DNN-for-Human-Action-Prediction\dataset\raw_data\real-life-voilence-non-voilence-dataset
extract_frames(
    input_directory="./raw_data/real-life-voilence-non-voilence-dataset/Violence", 
    output_directory="./cleaned-dataset/violent", 
    size=(224, 224))
# Out:
# Done V_1.mp4
# Done V_10.mp4
# Done V_100.mp4
# Done V_1000.mp4
# Done V_101.mp4
# Done V_102.mp4
# Done V_103.mp4
# Done V_104.mp4
# Done V_105.mp4
# Done V_106.mp4
# Done V_107.mp4
# Done V_108.mp4
# Done V_109.mp4
# Done V_11.mp4
# Done V_110.mp4
# Done V_111.mp4
# Done V_112.mp4
# Done V_113.mp4
# Done V_114.mp4
# Done V_115.mp4
# Done V_116.mp4
# Done V_117.mp4
# Done V_118.mp4
# Done V_119.mp4
# Done V_12.mp4
# Done V_120.mp4
# Done V_121.mp4
# Done V_122.mp4
# Done V_123.mp4
# Done V_124.mp4
# Done V_125.mp4
# Done V_126.mp4
# Done V_127.mp4
# Done V_128.mp4
# Done V_129.mp4
# Done V_13.mp4
# Done V_130.mp4
# Done V_131.mp4
# Done V_132.mp4
# Done V_133.mp4
# Done V_134.mp4
# Done V_135.mp4
# Done V_136.mp4
# Done V_137.mp4
# Done V_138.mp4
# Done V_139.mp4
# Done V_14.mp4
# Done V_140.mp4
# Done V_141.mp4
# Done V_142.mp4
# Done V_143.mp4
# Done V_144.mp4
# Done V_145.mp4
# Done V_146.mp4
# Done V_147.mp4
# Done V_148.mp4
# Done V_149.mp4
# Done V_15.mp4
# Done V_150.mp4
# ...

# %%
# non violence
extract_frames(
    input_directory="./raw_data/real-life-voilence-non-voilence-dataset/NonViolence", 
    output_directory="./cleaned-dataset/non-violent", 
    size=(224, 224))
# Out:
# Done NV_1.mp4
# Done NV_10.mp4
# Done NV_100.mp4
# Done NV_1000.mp4
# Done NV_101.mp4
# Done NV_102.mp4
# Done NV_103.mp4
# Done NV_104.mp4
# Done NV_105.mp4
# Done NV_106.mp4
# Done NV_107.mp4
# Done NV_108.mp4
# Done NV_109.mp4
# Done NV_11.mp4
# Done NV_110.mp4
# Done NV_111.mp4
# Done NV_112.mp4
# Done NV_113.mp4
# Done NV_114.mp4
# Done NV_115.mp4
# Done NV_116.mp4
# Done NV_117.mp4
# Done NV_118.mp4
# Done NV_119.mp4
# Done NV_12.mp4
# Done NV_120.mp4
# Done NV_121.mp4
# Done NV_122.mp4
# Done NV_123.mp4
# Done NV_124.mp4
# Done NV_125.mp4
# Done NV_126.mp4
# Done NV_127.mp4
# Done NV_128.mp4
# Done NV_129.mp4
# Done NV_13.mp4
# Done NV_130.mp4
# Done NV_131.mp4
# Done NV_132.mp4
# Done NV_133.mp4
# Done NV_134.mp4
# Done NV_135.mp4
# Done NV_136.mp4
# Done NV_137.mp4
# Done NV_138.mp4
# Done NV_139.mp4
# Done NV_14.mp4
# Done NV_140.mp4
# Done NV_141.mp4
# Done NV_142.mp4
# Done NV_143.mp4
# Done NV_144.mp4
# Done NV_145.mp4
# Done NV_146.mp4
# Done NV_147.mp4
# ...

# %% [markdown]
# Real Life camera dataset

# %%
# fight
extract_frames(
    input_directory="./raw_data/reallife-camera-dataset/fight", 
    output_directory="./cleaned-dataset/violent", 
    size=(224, 224))
# Out:
# Done fi001.mp4
# Done fi002.mp4
# Done fi003.mp4
# Done fi004.mp4
# Done fi005.mp4
# Done fi006.mp4
# Done fi007.mp4
# Done fi008.mp4
# Done fi009.mp4
# Done fi010.mp4
# Done fi011.mp4
# Done fi012.mp4
# Done fi013.mp4
# Done fi014.mp4
# Done fi015.mp4
# Done fi016.mp4
# Done fi017.mp4
# Done fi018.mp4
# Done fi019.mp4
# Done fi020.mp4
# Done fi021.mp4
# Done fi022.mp4
# Done fi023.mp4
# Done fi024.mp4
# Done fi025.mp4
# Done fi026.mp4
# Done fi027.mp4
# Done fi028.mp4
# Done fi029.mp4
# Done fi030.mp4
# Done fi031.mp4
# Done fi032.mp4
# Done fi033.mp4
# Done fi034.mp4
# Done fi035.mp4
# Done fi036.mp4
# Done fi037.mp4
# Done fi038.mp4
# Done fi039.mp4
# Done fi040.mp4
# Done fi041.mp4
# Done fi042.mp4
# Done fi043.mp4
# Done fi044.mp4
# Done fi045.mp4
# Done fi046.mp4
# Done fi047.mp4
# Done fi048.mp4
# Done fi049.mp4
# Done fi050.mp4
# Done fi051.mp4
# Done fi052.mp4
# Done fi053.mp4
# Done fi054.mp4
# Done fi055.mp4
# Done fi056.mp4
# Done fi057.mp4
# Done fi058.mp4
# ...

# %%
# no fight
extract_frames(
    input_directory="./raw_data/reallife-camera-dataset/noFight", 
    output_directory="./cleaned-dataset/non-violent", 
    size=(224, 224))
# Out:
# Done nofi001.mp4
# Done nofi002.mp4
# Done nofi003.mp4
# Done nofi004.mp4
# Done nofi005.mp4
# Done nofi006.mp4
# Done nofi007.mp4
# Done nofi008.mp4
# Done nofi009.mp4
# Done nofi010.mp4
# Done nofi011.mp4
# Done nofi012.mp4
# Done nofi013.mp4
# Done nofi014.mp4
# Done nofi015.mp4
# Done nofi016.mp4
# Done nofi017.mp4
# Done nofi018.mp4
# Done nofi019.mp4
# Done nofi020.mp4
# Done nofi021.mp4
# Done nofi022.mp4
# Done nofi023.mp4
# Done nofi024.mp4
# Done nofi025.mp4
# Done nofi026.mp4
# Done nofi027.mp4
# Done nofi028.mp4
# Done nofi029.mp4
# Done nofi030.mp4
# Done nofi031.mp4
# Done nofi032.mp4
# Done nofi033.mp4
# Done nofi034.mp4
# Done nofi035.mp4
# Done nofi036.mp4
# Done nofi037.mp4
# Done nofi038.mp4
# Done nofi039.mp4
# Done nofi040.mp4
# Done nofi041.mp4
# Done nofi042.mp4
# Done nofi043.mp4
# Done nofi044.mp4
# Done nofi045.mp4
# Done nofi046.mp4
# Done nofi047.mp4
# Done nofi048.mp4
# Done nofi049.mp4
# Done nofi050.mp4
# Done nofi051.mp4
# Done nofi052.mp4
# ...

# %% [markdown]
# SCDV_Converted Data

# %%
# Violent Test
extract_frames(
    input_directory="./raw_data/SCVD_converted/Test/Violence", 
    output_directory="./cleaned-dataset/violent", 
    size=(224, 224))

# Violent Train
extract_frames(
    input_directory="./raw_data/SCVD_converted/Train/Violence", 
    output_directory="./cleaned-dataset/violent", 
    size=(224, 224))
# Out:
# Done t_v001_converted.avi
# Done t_v002_converted.avi
# Done t_v003_converted.avi
# Done t_v004_converted.avi
# Done t_v005_converted.avi
# Done t_v006_converted.avi
# Done t_v007_converted.avi
# Done t_v008_converted.avi
# Done t_v009_converted.avi
# Done t_v010_converted.avi
# Done t_v011_converted.avi
# Done t_v012_converted.avi
# Done v001_converted.avi
# Done v002_converted.avi
# Done v003_converted.avi
# Done v004_converted.avi
# Done v006_converted.avi
# Done v007_converted.avi
# Done v008_converted.avi
# Done v009_converted.avi
# Done v010_converted.avi
# Done v011_converted.avi
# Done v012_converted.avi
# Done v013_converted.avi
# Done v014_converted.avi
# Done v015_converted.avi
# Done v016_converted.avi
# Done v017_converted.avi
# Done v018_converted.avi
# Done v019_converted.avi
# Done v020_converted.avi
# Done v021_converted.avi
# Done v022_converted.avi
# Done v023_converted.avi
# Done v024_converted.avi
# Done v025_converted.avi
# Done v026_converted.avi
# ...

# %%
# Non-Violent Test
extract_frames(
    input_directory="./raw_data/SCVD_converted/Test/Normal", 
    output_directory="./cleaned-dataset/non-violent", 
    size=(224, 224))

# Non-Violent Train
extract_frames(
    input_directory="./raw_data/SCVD_converted/Train/Normal", 
    output_directory="./cleaned-dataset/non-violent", 
    size=(224, 224))
# Out:
# Done t_n001_converted.avi
# Done t_n002_converted.avi
# Done t_n003_converted.avi
# Done t_n004_converted.avi
# Done t_n005_converted.avi
# Done t_n006_converted.avi
# Done t_n007_converted.avi
# Done t_n008_converted.avi
# Done t_n009_converted.avi
# Done t_n010_converted.avi
# Done t_n011_converted.avi
# Done t_n012_converted.avi
# Done t_n013_converted.avi
# Done t_n014_converted.avi
# Done t_n015_converted.avi
# Done t_n016_converted.avi
# Done t_n017_converted.avi
# Done t_n018_converted.avi
# Done t_n019_converted.avi
# Done t_n020_converted.avi
# Done t_n021_converted.avi
# Done t_n022_converted.avi
# Done t_n023_converted.avi
# Done t_n024_converted.avi
# Done t_n025_converted.avi
# Done t_n026_converted.avi
# Done t_n027_converted.avi
# Done t_n028_converted.avi
# Done t_n029_converted.avi
# Done t_n030_converted.avi
# Done t_n031_converted.avi
# Done t_n032_converted.avi
# Done t_n033_converted.avi
# Done t_n034_converted.avi
# Done t_n035_converted.avi
# ...

# %%
# Non-Violent Test
extract_frames(
    input_directory="./raw_data/SCVD_converted/Test/Weaponized", 
    output_directory="./cleaned-dataset/violent", 
    size=(224, 224))

# Non-Violent Train
extract_frames(
    input_directory="./raw_data/SCVD_converted/Train/Weaponized", 
    output_directory="./cleaned-dataset/violent", 
    size=(224, 224))
