# %%
# setting root at top

import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

# %% [markdown]
# # OptimizedModel 224x224 Image and 5 Conv Blocks
# # Using Class Weight + OverSampler
# # Adam Optimizer with lr = 1e-3

# %% [markdown]
# ### Import libraries
# * `torch`
# * `datasets` and `transforms` from `torchvision` for data Loading.
# * `DataLoader` from `torch.utils.data` for Batching and using data in model.
# * `OptimizedModel` from `architectures.OptimizedModel.py`
# * `pandas` as `pd`
# * `matplotlib.pyplot` as `plt`
# * `seaborn` as sns
# * `trainer` from `modules.TrainTest`
# * `oversampler` from `modules.OverSampler`
# * `compute_class_weights` from `modules.ClassWeights`

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from architectures.OptimizedModel import OptimizedModel

# visualization
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#trainer and tester modules
from modules.TrainTest import trainer
from modules.ClassWeights import compute_class_weights
from modules.OverSampler import  oversampler

# %% [markdown]
# ### Load datasets for training
# * load 224x224 images
# * load from `../dataset/final-dataset/train`
# * convert to tensor
# * make batch_size = 16

# %%
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(p=0.35),
    transforms.RandomRotation(8),
    transforms.ColorJitter(
        brightness=0.2,
        contrast=0.2
    ),
    transforms.ToTensor(),
    transforms.RandomErasing(p=0.3)
])

train_dataset = datasets.ImageFolder(
    root="../dataset/final-dataset/train",
    transform=train_transform
)

sampler = oversampler(dataset=train_dataset, oversample_rate=1)

# %%
train_dataloader = DataLoader(
    dataset=train_dataset,
    shuffle=False,
    sampler= sampler,
    pin_memory=True,
    batch_size=32,
    num_workers=2,
    persistent_workers=True    
    )

class_weight = compute_class_weights(train_dataloader)

# %% [markdown]
# ### Load datasets for training
# * load 224x224 images
# * load from `../dataset/final-dataset/train`
# * convert to tensor
# * make batch_size = 32

# %%
valid_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])
valid_dataset = datasets.ImageFolder(
    root="../dataset/final-dataset/valid",
    transform=valid_transform
)
valid_dataloader = DataLoader(
    dataset=valid_dataset,
    batch_size=32,
    pin_memory=True,
    persistent_workers=True,
    num_workers = 2
)

# %% [markdown]
# ## Use Model and Set Optimizers

# %% [markdown]
# * conv_layers = 4
# * normalizations = [1,1,1,1]
# * poolings = [1,1,1,1]
# * dropouts = [0,1,0,1],
# * initial_output_channel = 32,
# * initial_image_size = 224,
# * class_weights = class_weights,
# * num_classes = 3

# %%
model = OptimizedModel(
    conv_layers=4,
    normalizations = [1,1,1,1],
    poolings = [1,1,1,1],
    dropouts = [0,1,0,1],
    initial_output_channel = 32,
    initial_image_size = 224,
    class_weights = class_weight,
    num_classes = 3,
    dropout_p = 0.2
).to("cuda")

# %%
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3)
model.set_optimizer(optimizer=optimizer)

# %% [markdown]
# ### Use trainer to train model

# %%
metrics = trainer(
    model = model,
    train_dataloader = train_dataloader,
    test_dataloader = valid_dataloader,
    epoch = 100,
    lr = 1e-3,
    print_on=2,
    save_dir = "../models/opt_img224_c4_adam_1e-3_b32_v2",
    save_checkpoints=1,
    checkpoint_name = "opt_img224_c4_b32_",
)
# Out:
# Epoch 2/100 | Train Loss: 0.9538 | Valid Loss: 1.0753
# Epoch 4/100 | Train Loss: 0.5985 | Valid Loss: 0.7242
# Epoch 6/100 | Train Loss: 0.4713 | Valid Loss: 0.7237
# Epoch 8/100 | Train Loss: 0.4184 | Valid Loss: 1.2494
# Epoch 10/100 | Train Loss: 0.3528 | Valid Loss: 0.7198
# Epoch 12/100 | Train Loss: 0.3386 | Valid Loss: 0.7349
# Epoch 14/100 | Train Loss: 0.2892 | Valid Loss: 1.1828
# Epoch 16/100 | Train Loss: 0.2682 | Valid Loss: 0.7249
# Epoch 18/100 | Train Loss: 0.2543 | Valid Loss: 0.8107
# Epoch 20/100 | Train Loss: 0.2380 | Valid Loss: 0.6884
# Epoch 22/100 | Train Loss: 0.2027 | Valid Loss: 0.7807
# Epoch 24/100 | Train Loss: 0.2289 | Valid Loss: 0.7168
# Epoch 26/100 | Train Loss: 0.1887 | Valid Loss: 0.7436
# Epoch 28/100 | Train Loss: 0.1797 | Valid Loss: 0.7979
# Epoch 30/100 | Train Loss: 0.1927 | Valid Loss: 0.9825
# Epoch 32/100 | Train Loss: 0.1569 | Valid Loss: 0.7608
# Epoch 34/100 | Train Loss: 0.1509 | Valid Loss: 0.9151
# Epoch 36/100 | Train Loss: 0.1762 | Valid Loss: 0.9862
# Epoch 38/100 | Train Loss: 0.1461 | Valid Loss: 0.9081
# Epoch 40/100 | Train Loss: 0.1529 | Valid Loss: 0.8970
# Epoch 42/100 | Train Loss: 0.1414 | Valid Loss: 0.9144
# Epoch 44/100 | Train Loss: 0.1195 | Valid Loss: 0.9496
# Epoch 46/100 | Train Loss: 0.1208 | Valid Loss: 1.2114
# Epoch 48/100 | Train Loss: 0.1148 | Valid Loss: 0.9780
# Epoch 50/100 | Train Loss: 0.1186 | Valid Loss: 0.9932
# Epoch 52/100 | Train Loss: 0.1064 | Valid Loss: 0.9454
# Epoch 54/100 | Train Loss: 0.1034 | Valid Loss: 1.0371
# Epoch 56/100 | Train Loss: 0.1235 | Valid Loss: 0.9717
# Epoch 58/100 | Train Loss: 0.1086 | Valid Loss: 0.9576
# Epoch 60/100 | Train Loss: 0.0873 | Valid Loss: 1.1123
# Epoch 62/100 | Train Loss: 0.0893 | Valid Loss: 0.8874
# Epoch 64/100 | Train Loss: 0.1008 | Valid Loss: 0.9253
# Epoch 66/100 | Train Loss: 0.0869 | Valid Loss: 1.1991
# Epoch 68/100 | Train Loss: 0.1071 | Valid Loss: 0.9486
# Epoch 70/100 | Train Loss: 0.0826 | Valid Loss: 1.0157
# Epoch 72/100 | Train Loss: 0.0856 | Valid Loss: 1.0228
# Epoch 74/100 | Train Loss: 0.0823 | Valid Loss: 1.0691
# Epoch 76/100 | Train Loss: 0.0782 | Valid Loss: 1.8078
# Epoch 78/100 | Train Loss: 0.0705 | Valid Loss: 1.1848
# Epoch 80/100 | Train Loss: 0.0787 | Valid Loss: 1.0476
# Epoch 82/100 | Train Loss: 0.0923 | Valid Loss: 1.1705
# Epoch 84/100 | Train Loss: 0.0763 | Valid Loss: 0.9418
# Epoch 86/100 | Train Loss: 0.0673 | Valid Loss: 0.9787
# Epoch 88/100 | Train Loss: 0.0634 | Valid Loss: 1.1633
# Epoch 90/100 | Train Loss: 0.0870 | Valid Loss: 0.9564
# Epoch 92/100 | Train Loss: 0.0655 | Valid Loss: 1.3315
# Epoch 94/100 | Train Loss: 0.0636 | Valid Loss: 1.2610
# Epoch 96/100 | Train Loss: 0.0626 | Valid Loss: 1.0575
# Epoch 98/100 | Train Loss: 0.0647 | Valid Loss: 1.2771
# Epoch 100/100 | Train Loss: 0.0652 | Valid Loss: 1.2440

# %% [markdown]
# ## Visualize

# %% [markdown]
# Convert metrics to a pd.DataFrame and add epoch column for visualization.

# %%
metrics = pd.DataFrame(metrics)
epochs = [i+1 for i  in range(len(metrics))]
metrics["epoch"] = epochs

# %%
metrics = metrics[0:50]

# %%
fig, axes = plt.subplots(3, 2, figsize=(12, 8))
axes = axes.flatten()

to_viz = [
    "loss",
    "accuracy",
    "precision",
    "recall",
    "f1"
]

for i, metric in enumerate(to_viz):

    ax = axes[i]

    sns.lineplot(
        data=metrics,
        x="epoch",
        y=f"training_{metric}",
        ax=ax,
        label="train"
    )

    sns.lineplot(
        data=metrics,
        x="epoch",
        y=f"valid_{metric}",
        ax=ax,
        label="valid"
    )

    ax.set_title(metric.capitalize())
    ax.set_xlabel("Epoch")
    ax.set_ylabel(metric.capitalize())

# Hide unused subplot (6th slot)
axes[-1].axis("off")

plt.tight_layout()
plt.show()
